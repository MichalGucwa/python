# %% [markdown]
# # EXERCISE 11.1

# %% [markdown]
# Solve the 1D heat equation with initial and bondary conditions not used during the classes. Send the script and the figure.

# %%
import math
import numpy as np
from matplotlib import pyplot as plt

D, Nx, Nt, L, T=1.0, 20,  250, 1.0, 0.1

t = np.linspace(0,T,num=Nt+1, dtype=float)
x = np.linspace(0,L,num=Nx+1, dtype=float)

dx = x[1] - x[0]
dt = t[1] - t[0]

r=D*dt / (dx*dx)
print("r = %.2f" % r)
assert r < 0.5

u=np.empty((Nx+1,Nt+1),dtype=float)

# initial condition t=0
#u[:,0]=0.5* (np.sign(x-0.4)+np.sign(0.6-x)) #used
# u[:,0]=np.where(x<0.5, 2*x,2*(1-x)) #not used
u[:,:]=0

#boundary conditions
# u[0,:]=0.0 #cold end
# u[Nx,:]=0.0 #cold end
u[0,:]=1.0 #hot end
u[Nx,:]=1.0 #hot end

for j in range(Nt):
    u[1:-1,j+1]=r*u[:-2,j]+ (1-2*r) * u[1:-1,j]  + r*u[2:,j]

# print(u)

plt.title("1D heat equation")
plt.xlabel('time')
plt.ylabel('x')
# plt.imshow(u, cmap='hot', interpolation='nearest')
plt.imshow(u[:,::3], cmap='hot', interpolation='nearest')
plt.imshow(u[:,::3], cmap='hot', interpolation='bilinear')
# Out:
# r = 0.16

# %% [markdown]
# # EXERCISE 11.2

# %% [markdown]
# Solve the 1D wave equation with initial and bondary conditions not used during the classes. Send the script and the figure.
#
# Note that u(x,0) (the position of the strig) should be continous and consistent with boundary conditions.

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, T, num=Nt+1)
y = np.linspace(0, L,num=Nx+1)
X, Y = np.meshgrid(t, y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, u, 50, cmap='hot')
ax.set_xlabel('time')
ax.set_ylabel('position')
ax.set_zlabel('temp')
ax.view_init(10, -120)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, u, 50, cmap='hot')
ax.set_xlabel('time')
ax.set_ylabel('position')
ax.set_zlabel('temp')


ax.view_init(20, 180)
